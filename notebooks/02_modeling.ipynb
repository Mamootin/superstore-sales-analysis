# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
import pandas as pd
from src.data_prep import load_orders, clean_orders
from src.features import build_features
from src.model import train_baseline, train_random_forest

# %%
df = clean_orders(load_orders("../data/raw/Superstore.xlsx"))
X, y = build_features(df)

# %%
model = train_random_forest(X, y)
# Out:
# MAE: 26.01204941838222
# R2: -0.03416862286977129

# %%
importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
print(importances.head(10))
# Out:
# Sales                    0.744056
# Discount                 0.160879
# Quantity                 0.012785
# Sub-Category_Binders     0.009703
# Category_Furniture       0.007227
# Sub-Category_Copiers     0.006665
# Segment_Consumer         0.005381
# Region_Central           0.004573
# Sub-Category_Supplies    0.004366
# Sub-Category_Machines    0.004085
# dtype: float64

# %%
joblib.dump(model, "../app/profit_model.joblib")
# Out:
# ['../app/profit_model.joblib']
